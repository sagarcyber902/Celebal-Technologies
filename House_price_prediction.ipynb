# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
features = ['OverallQual', 'OverallCond']
x_train = train[features]
x_test = test[features]
y_train = train['SalePrice']

# %%
model = LinearRegression()
model.fit(x_train,y_train)
predictions = model.predict(x_test)

# %%
submission = test[['Id']]
submission
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
submission['SalePrice'] = predictions
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18568\2834354856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['SalePrice'] = predictions

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461  130845.895547
# 1     1462  176254.328223
# 2     1463  131215.902091
# 3     1464  176254.328223
# 4     1465  267441.200117
# ...    ...            ...
# 1454  2915   85067.456329
# 1455  2916   85807.469416
# 1456  2917  130475.889004
# 1457  2918  131215.902091
# 1458  2919  222032.767441
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('submisssion_house.csv', index=None)

# %%
numeric_columns = train.select_dtypes(include=['number']).columns
train[numeric_columns] = train[numeric_columns].fillna(train[numeric_columns].median(), inplace=False)

# %%
numeric_columns = test.select_dtypes(include=['number']).columns
test[numeric_columns] = test[numeric_columns].fillna(test[numeric_columns].median(), inplace=False)

# %%
train=pd.get_dummies(train)

# %%
test=pd.get_dummies(test)

# %%
train, test = train.align(test, join='inner', axis=1)
train
